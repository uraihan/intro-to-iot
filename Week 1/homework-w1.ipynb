# %% [markdown]
# # BL40A2010 Introduction to IoT-Based Systems
#
# ## Assignment 1, 14.12.2021
#
# ### Author: Umair Raihan

# %% [markdown]
# **(1) Analyze an electric heater as a system following Example 1.1.**

# %% [markdown]
# Answer:
#
# OP - Peculiar operation         : Convert electric power to heat energy \
# C1 - Conditions of production   : Resistor can convert electric current into heat energy using the Joule heating principle \
# C2 - Conditions of reproduction : Periodic maintenance (thorough cleaning once or twice every year), proper connection to power outlet \
# C3 - External Condition         : Electricity blackout, dust accumulating and blocking the resistors that produce heat, window broken and cold air 'outperform' heat energy produced by the heater

# %% [markdown]
# **(2) Give one example for each scientific rationalities presented in Section 1.2.1 similar to Example 1.2.**

# %% [markdown]
# Answer:
# #### The rationalities of the shape of the Earth
# Classical -> The shape of the Earth has been a subject of scientific debates and observations for thousands and thousands of years, and it has been proven time and time again that the shape of the Earth is spherical. \
# Non-Classical -> Mathematical and physical models can be modeled to prove the spherical nature of the shape of the Earth. \
# Interventionist -> After being a subject of debate for many many years, with the advancement of technology scientists and skeptics alike can now intervene by going directly to the space to see by their own eyes and prove their own theory once and for all.

# %% [markdown]
# **(3) Download the air temperature data of one year from [FMI](http://en.ilmatieteenlaitos.fi/download-observations#!/) at the city/region you currently live. Make four (arbitrary) time series plots for one year, one month, one week and one day.**
#
# *Hint:* Code like in the tutorial notebook.

# %%
#!pip install numpy

# %%
#Import libraries
import pandas as pd #https://pandas.pydata.org/
import matplotlib.pyplot as plt #https://matplotlib.org/
import matplotlib.dates as mdates #https://matplotlib.org/
import numpy as np #http://www.numpy.org/
#from datetime import date #https://docs.python.org/3/library/datetime.html

# %% [markdown]
# ### Importing data from CSV file obtained from the FMI website

# %%
AirTemp = pd.read_csv("temp-lpr-lepola-2020-2021.csv", 
                        sep=",", 
                        header=0,
                        parse_dates= {"date" : ["Year","m","d","Time"]},
                        index_col=0,
                        usecols=[0,1,2,3,5])

AirTemp.info();
AirTemp[:25]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8785 entries, 2020-12-13 00:00:00 to 2021-12-14 00:00:00
# Data columns (total 1 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Air temperature (degC)  8774 non-null   float64
# dtypes: float64(1)
# memory usage: 137.3 KB
#                      Air temperature (degC)
# date
# 2020-12-13 00:00:00                    -5.5
# 2020-12-13 01:00:00                    -5.2
# 2020-12-13 02:00:00                    -4.9
# 2020-12-13 03:00:00                    -4.8
# 2020-12-13 04:00:00                    -4.8
# 2020-12-13 05:00:00                    -4.5
# 2020-12-13 06:00:00                    -4.6
# 2020-12-13 07:00:00                    -5.6
# 2020-12-13 08:00:00                    -5.9
# 2020-12-13 09:00:00                    -5.4
# 2020-12-13 10:00:00                    -5.5
# 2020-12-13 11:00:00                    -5.3
# ...

# %% [markdown]
# ### Plot #1: Data of one day measurement in Lappeenranta Lepola (13 December 2020)

# %%
fig, ax = plt.subplots(figsize=(16, 6))

ax.plot(AirTemp['2020-12-13'], color='tab:orange', label='Air Temperature')
ax.set_xlabel('Time')
ax.set_ylabel('Air Temperature')
ax.set_title('Air Temperature Measurement in Lappeenranta Lepola Station (13 December 2020)')
ax.grid(True)

xfmt = mdates.DateFormatter('%H:%M')
ax.xaxis.set_major_formatter(xfmt)
plt.show()
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Plot #2: Data of Week 30 measurement (26 July 2021 - 1 July 2021)

# %%
fig, ax = plt.subplots(figsize=(16, 6))

ax.plot(AirTemp['2021-06-26':'2021-07-01'], color='tab:blue', label='Air Temperature')
ax.set_xlabel('Date')
ax.set_ylabel('Air Temperature')
ax.set_title('Week 30 Air Temperature Measurement in Lappeenranta Lepola Station')
ax.grid(True)

# %% [markdown]
# ### Plot #3: Air temperature measurement on March 2021

# %%
fig, ax = plt.subplots(figsize=(16, 6))

ax.plot(AirTemp['2021-06-26'], color='tab:green', label='Air Temperature')
ax.set_xlabel('Date')
ax.set_ylabel('Air Temperature')
ax.set_title('Air Temperature Measurement in Lappeenranta Lepola Station On March 2021')
ax.grid(True)
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Plot #4: Air Temperature measurement in a year (December 2020 - December 2021)

# %%
fig, ax = plt.subplots(figsize=(16, 6))

ax.plot(AirTemp, color='tab:purple', label='Air Temperature')
ax.set_xlabel('Date')
ax.set_ylabel('Air Temperature')
ax.set_title('Air Temperature Measurement in Lappeenranta Lepola Station On March 2021')
ax.grid(True)

# %% [markdown]
# **(4) Consider a house with an electric heater. How the electricity consumption of the heater would be affected by the air temperature? Is there a way to change this?**

# %% [markdown]
# Answer:
#
# The lower the temperature is in the house, the more electricity needed by the heater to heat up the house into a certain level of temperature, thus increasing the amount of electricity consumption. One way to help this issue is to reinforce the house with a good insulation to help heating up the house without a constant need of the heater. Another solution is to implement what is called passive solar heating design, which is a house design that use the energy of the sun to heat up the house.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6e014854-0d33-4882-b3ba-5e4227a689e6' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
